# %%
import xarray as xr

ds = xr.open_dataset("/home/rulestools/ERA5-to-CERRA_Fabio_Marizzi/data/cerra/cerra_si10_2009.nc")
print(ds)                  # overview: dims, coords, variables
# Out:
# <xarray.Dataset> Size: 13GB
# Dimensions:     (valid_time: 2920, y: 1069, x: 1069)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 23kB 2009-01-01 ... 2009-12-31T21...
#     expver      (valid_time) <U4 47kB ...
#     latitude    (y, x) float64 9MB ...
#     longitude   (y, x) float64 9MB ...
# Dimensions without coordinates: y, x
# Data variables:
#     si10        (valid_time, y, x) float32 13GB ...
# Attributes:
#     GRIB_centre:             eswi
#     GRIB_centreDescription:  Norrkoping
#     GRIB_subCentre:          255
#     Conventions:             CF-1.7
#     institution:             Norrkoping
#     history:                 2026-06-29T12:02 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
var = ds["si10"]
print(var)
# Out:
# <xarray.DataArray 'si10' (valid_time: 2920, y: 1069, x: 1069)> Size: 13GB
# [3336862120 values with dtype=float32]
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 23kB 2009-01-01 ... 2009-12-31T21...
#     expver      (valid_time) <U4 47kB ...
#     latitude    (y, x) float64 9MB ...
#     longitude   (y, x) float64 9MB ...
# Dimensions without coordinates: y, x
# Attributes: (12/35)
#     GRIB_paramId:                             207
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1142761
#     GRIB_typeOfLevel:                         heightAboveGround
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10si
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre wind speed
# ...

# %%
import matplotlib.pyplot as plt
ds["si10"].isel(valid_time=10).plot(cmap="viridis")
plt.show()
